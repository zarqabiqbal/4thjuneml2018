# %%
import matplotlib.pyplot as plt
import seaborn as sns
iris = sns.load_dataset("iris")
iris["ID"] = iris.index
iris["ratio"] = iris["sepal_length"]/iris["sepal_width"]

sns.lmplot(x="ID", y="ratio", data=iris, hue="species", fit_reg=False, legend=False)

plt.legend()
plt.show()

# %%
#################################Graph of Breast Cancer Datasets###############################################

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm

breast=load_breast_cancer() 

trained_data,test_data,trained_target,test_target=train_test_split(breast.data,breast.target,test_size=0.1)

#load Algorithms
dsc=tree.DecisionTreeClassifier()
knnc=KNeighborsClassifier(n_neighbors=3)
svcc=svm.SVC()

#trained data with diffrent algorithms
dsctrained=dsc.fit(trained_data,trained_target)
knnctrained=knnc.fit(trained_data,trained_target)
svcctrained=svcc.fit(trained_data,trained_target)

#get predict output with diffrent algorithms
dscpredicted_output=dsctrained.predict(test_data)
knncpredicted_output=knnctrained.predict(test_data)
svccpredicted_output=svcctrained.predict(test_data)

#check accuracy of algorithms
pct_dsc=accuracy_score(test_target,dscpredicted_output)*100
pct_knn=accuracy_score(test_target,knncpredicted_output)*100
pct_svc=accuracy_score(test_target,svccpredicted_output)*100

print("DSC ALGO ACCURACY :",pct_dsc,"%")
print("KNN ALGO ACCURACY :",pct_knn,"%")
print("SVC ALGO ACCURACY :",pct_svc,"%")


plt.xlabel("<--------Algorithms-------->")
plt.ylabel("<--------Accuracy of Algorithms-------->")
plt.title("Graph Of Breast_Cancer_Datasets Algorithm Accuracy with Diffrent Algo")
plt.axis([-1,3,0,100])
plt.grid(color='grey')
plt.bar(['DSC','KNN','SVM'],[pct_dsc,pct_knn,pct_svc],color='orange')
plt.show()
# Out:
# DSC ALGO ACCURACY : 92.98245614035088 %
# KNN ALGO ACCURACY : 89.47368421052632 %
# SVC ALGO ACCURACY : 61.40350877192983 %

# %%
#######################################Graph of Iris Datasets###############################################


from sklearn.datasets import load_iris
iris=load_iris() 

trained_data,test_data,trained_target,test_target=train_test_split(iris.data,iris.target,test_size=0.1)

#load Algorithms
dsc=tree.DecisionTreeClassifier()
knnc=KNeighborsClassifier(n_neighbors=3)
svcc=svm.SVC()

#trained data with diffrent algorithms
dsctrained=dsc.fit(trained_data,trained_target)
knnctrained=knnc.fit(trained_data,trained_target)
svcctrained=svcc.fit(trained_data,trained_target)

#get predict output with diffrent algorithms
dscpredicted_output=dsctrained.predict(test_data)
knncpredicted_output=knnctrained.predict(test_data)
svccpredicted_output=svcctrained.predict(test_data)

#check accuracy of algorithms
pct_dsc=accuracy_score(test_target,dscpredicted_output)*100
pct_knn=accuracy_score(test_target,knncpredicted_output)*100
pct_svc=accuracy_score(test_target,svccpredicted_output)*100

print("DSC ALGO ACCURACY :",pct_dsc,"%")
print("KNN ALGO ACCURACY :",pct_knn,"%")
print("SVC ALGO ACCURACY :",pct_svc,"%")


plt.xlabel("<--------Algorithms-------->")
plt.ylabel("<--------Accuracy of Algorithms-------->")
plt.title("Graph Of Iris_Datasets Algorithm Accuracy with Diffrent Algo")
plt.axis([-1,3,0,100])
plt.grid(color='grey')
plt.bar(['DSC','KNN','SVM'],[pct_dsc,pct_knn,pct_svc],color='orange')
plt.show()
# Out:
# DSC ALGO ACCURACY : 100.0 %
# KNN ALGO ACCURACY : 100.0 %
# SVC ALGO ACCURACY : 100.0 %

# %%
#######################################Graph of Diabetes Datasets#################################################


from sklearn.datasets import load_diabetes
diabetes=load_diabetes() 

trained_data,test_data,trained_target,test_target=train_test_split(diabetes.data,diabetes.target,test_size=0.4)

#load Algorithms
dsc=tree.DecisionTreeClassifier()
knnc=KNeighborsClassifier(n_neighbors=3)
svcc=svm.SVC()

#trained data with diffrent algorithms
dsctrained=dsc.fit(trained_data,trained_target)
knnctrained=knnc.fit(trained_data,trained_target)
svcctrained=svcc.fit(trained_data,trained_target)

#get predict output with diffrent algorithms
dscpredicted_output=dsctrained.predict(test_data)
knncpredicted_output=knnctrained.predict(test_data)
svccpredicted_output=svcctrained.predict(test_data)

#check accuracy of algorithms
pct_dsc=accuracy_score(test_target,dscpredicted_output)*100
pct_knn=accuracy_score(test_target,knncpredicted_output)*100
pct_svc=accuracy_score(test_target,svccpredicted_output)*100

print("DSC ALGO ACCURACY :",pct_dsc,"%")
print("KNN ALGO ACCURACY :",pct_knn,"%")
print("SVC ALGO ACCURACY :",pct_svc,"%")


plt.xlabel("<--------Algorithms-------->")
plt.ylabel("<--------Accuracy of Algorithms-------->")
plt.title("Graph Of Diabetes_Datasets Algorithm Accuracy With Diffrent Algo")
plt.grid(color='grey')
plt.bar(['DSC','KNN','SVM'],[pct_dsc,pct_knn,pct_svc],color='orange')
plt.show()
# Out:
# DSC ALGO ACCURACY : 1.1299435028248588 %
# KNN ALGO ACCURACY : 0.0 %
# SVC ALGO ACCURACY : 0.0 %

# %%
######################################Graph of Digits Datasets##################################################


from sklearn.datasets import load_digits

digits=load_digits() 

trained_data,test_data,trained_target,test_target=train_test_split(digits.data,digits.target,test_size=0.1)

#load Algorithms
dsc=tree.DecisionTreeClassifier()
knnc=KNeighborsClassifier(n_neighbors=3)
svcc=svm.SVC()

#trained data with diffrent algorithms
dsctrained=dsc.fit(trained_data,trained_target)
knnctrained=knnc.fit(trained_data,trained_target)
svcctrained=svcc.fit(trained_data,trained_target)

#get predict output with diffrent algorithms
dscpredicted_output=dsctrained.predict(test_data)
knncpredicted_output=knnctrained.predict(test_data)
svccpredicted_output=svcctrained.predict(test_data)

#check accuracy of algorithms
pct_dsc=accuracy_score(test_target,dscpredicted_output)*100
pct_knn=accuracy_score(test_target,knncpredicted_output)*100
pct_svc=accuracy_score(test_target,svccpredicted_output)*100

print("DSC ALGO ACCURACY :",pct_dsc,"%")
print("KNN ALGO ACCURACY :",pct_knn,"%")
print("SVC ALGO ACCURACY :",pct_svc,"%")


plt.xlabel("<--------Algorithms-------->")
plt.ylabel("<--------Accuracy of Algorithms-------->")
plt.title("Graph Of Digits_Datasets Algorithm Accuracy")
plt.grid(color='grey')
plt.bar(['DSC','KNN','SVM'],[pct_dsc,pct_knn,pct_svc],color='orange')
plt.show()
# Out:
# DSC ALGO ACCURACY : 83.88888888888889 %
# KNN ALGO ACCURACY : 99.44444444444444 %
# SVC ALGO ACCURACY : 46.666666666666664 %

# %%
########################################Graph of Wine Datasets####################################################


from sklearn.datasets import load_wine

wine=load_wine() 

trained_data,test_data,trained_target,test_target=train_test_split(wine.data,wine.target,test_size=0.1)

#load Algorithms
dsc=tree.DecisionTreeClassifier()
knnc=KNeighborsClassifier(n_neighbors=3)
svcc=svm.SVC()

#trained data with diffrent algorithms
dsctrained=dsc.fit(trained_data,trained_target)
knnctrained=knnc.fit(trained_data,trained_target)
svcctrained=svcc.fit(trained_data,trained_target)

#get predict output with diffrent algorithms
dscpredicted_output=dsctrained.predict(test_data)
knncpredicted_output=knnctrained.predict(test_data)
svccpredicted_output=svcctrained.predict(test_data)

#check accuracy of algorithms
pct_dsc=accuracy_score(test_target,dscpredicted_output)*100
pct_knn=accuracy_score(test_target,knncpredicted_output)*100
pct_svc=accuracy_score(test_target,svccpredicted_output)*100

print("DSC ALGO ACCURACY :",pct_dsc,"%")
print("KNN ALGO ACCURACY :",pct_knn,"%")
print("SVC ALGO ACCURACY :",pct_svc,"%")


plt.xlabel("<--------Algorithms-------->")
plt.ylabel("<--------Accuracy of Algorithms-------->")
plt.title("Graph Of Wine_Datasets Algorithm Accuracy")
plt.grid(color='grey')
plt.bar(['DSC','KNN','SVM'],[pct_dsc,pct_knn,pct_svc],color='orange')
plt.show()
# Out:
# DSC ALGO ACCURACY : 88.88888888888889 %
# KNN ALGO ACCURACY : 61.111111111111114 %
# SVC ALGO ACCURACY : 44.44444444444444 %
